# %% [markdown]
# # Lab api wrappers

# %%
#!pip install spotipy

# %%
# 📚 Import libraries
import pprint #Thanks to my ISI <3
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
import time

# %% [markdown]
# Search for an artist

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> Used only to test how is working. For solution please scroll down </div>

# %%
#Trying seach for an artist
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="ab2abec36e6d42faa859d91cb844ca37",
                                                           client_secret="d07e0208deb5443b9f5195b52a09b790"))

results = sp.search(q='Britney Spears', limit=1, type='artist')  ### type!
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Britney+Spears&type=artist&offset=0&limit=1',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#     'followers': {'href': None, 'total': 12473285},
#     'genres': ['dance pop', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#     'id': '26dSoYclwsYLMAKD3tpOr4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb4e7e6ded87a4e0f65b5afcec',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051744e7e6ded87a4e0f65b5afcec',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1784e7e6ded87a4e0f65b5afcec',
#       'width': 160}],
#     'name': 'Britney Spears',
#     'popularity': 79,
#     'type': 'artist',
#     'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#   'limit': 1,
# ...

# %%
results = sp.search(q='Rosalia', limit=1, type='artist')  ### type!
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Rosalia&type=artist&offset=0&limit=1',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#     'followers': {'href': None, 'total': 7472288},
#     'genres': ['pop', 'r&b en espanol'],
#     'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#     'id': '7ltDVBr6mKbRvohxheJ9h1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebd7bb678bef6d2f26110cae49',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174d7bb678bef6d2f26110cae49',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178d7bb678bef6d2f26110cae49',
#       'width': 160}],
#     'name': 'ROSALÍA',
#     'popularity': 84,
#     'type': 'artist',
#     'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#   'limit': 1,
# ...

# %%
#Link to my playlist just here copied to not forget it 
3sKSLGn6P4YYtSsMOHOl16?si=ad2c6d1a541f4ee8
# Out:
#   Cell In[4], line 2
#     3sKSLGn6P4YYtSsMOHOl16?si=ad2c6d1a541f4ee8
#     ^
# SyntaxError: invalid decimal literal

# %%
results.keys()
# Out:
# dict_keys(['artists'])

# %%
playlist = sp.user_playlist_tracks("spotify", "3sKSLGn6P4YYtSsMOHOl16")
playlist#.keys() # Let's look at items and total:
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3sKSLGn6P4YYtSsMOHOl16/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-01-22T15:28:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
# ...

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3sKSLGn6P4YYtSsMOHOl16/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-01-22T15:28:12Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#                          'href': 'https://api.spotify.com/v1/users/luisja90',
#                          'id': 'luisja90',
#                          'type': 'user',
#                          'uri': 'spotify:user:luisja90'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                              'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                              'id': '5YGY8feqx7naU7z4HrwZM6',
# ...

# %% [markdown]
# Checking all the options to see what they do or contains

# %%
playlist["total"]
# Out:
# 30

# %%
playlist["href"]
# Out:
# 'https://api.spotify.com/v1/playlists/3sKSLGn6P4YYtSsMOHOl16/tracks?offset=0&limit=100&additional_types=track'

# %%
len(playlist["items"])
# Out:
# 30

# %%
playlist["limit"]
# Out:
# 100

# %%
playlist["next"]

# %%
playlist["offset"]
# Out:
# 0

# %%
playlist["previous"]

# %% [markdown]
# I have 30 songs in this playlist and the items are 30 so I can download them

# %%
### OPTION 1
results = sp.user_playlist_tracks("spotify", "3sKSLGn6P4YYtSsMOHOl16")
songs = results['items']

while results['next']:
    results = sp.next(results)
    songs.extend(results['items'])
len(songs)
# Out:
# 30

# %% [markdown]
# The tedious investigation of where the hell the information is
# <div class="alert alert-block alert-info"> <b>NOTE</b> Used only to test how is working. For solution please scroll down </div>

# %%
#- songs[0]['track']['id'] #Track id
#- songs[0]['track']['duration_ms'] #duration
#- songs[0]['track']['name'] #Song name
#- songs[0]['track']['popularity'] #Popularity

# %%
songs[0]
# Out:
# {'added_at': '2023-01-22T15:28:12Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#   'href': 'https://api.spotify.com/v1/users/luisja90',
#   'id': 'luisja90',
#   'type': 'user',
#   'uri': 'spotify:user:luisja90'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#      'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#      'id': '5YGY8feqx7naU7z4HrwZM6',
#      'name': 'Miley Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
# ...

# %%
songs[0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
songs[0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
songs[0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#     'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#     'id': '5YGY8feqx7naU7z4HrwZM6',
#     'name': 'Miley Cyrus',
#     'type': 'artist',
#     'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
# ...

# %%
songs[0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
songs[0]['track']['duration_ms'] #duration
# Out:
# 200454

# %%
songs[0]['track']['name']
# Out:
# 'Flowers'

# %%
songs[0]['track']['popularity']
# Out:
# 97

# %%
songs[0]['track']['id']
# Out:
# '0yLdNVWF3Srea0uzk55zFn'

# %%
songs[0]['track']['artists'][0]#['name']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#  'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#  'id': '5YGY8feqx7naU7z4HrwZM6',
#  'name': 'Miley Cyrus',
#  'type': 'artist',
#  'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}

# %%
songs[0]['track']['artists'][0]['name']#['name']
# Out:
# 'Miley Cyrus'

# %% [markdown]
# How to get track features

# %%
example_song=sp.audio_features(tracks=["0yLdNVWF3Srea0uzk55zFn"])
example_song
# Out:
# [{'danceability': 0.707,
#   'energy': 0.681,
#   'key': 0,
#   'loudness': -4.325,
#   'mode': 1,
#   'speechiness': 0.0668,
#   'acousticness': 0.0632,
#   'instrumentalness': 5.15e-06,
#   'liveness': 0.0322,
#   'valence': 0.646,
#   'tempo': 117.999,
#   'type': 'audio_features',
#   'id': '0yLdNVWF3Srea0uzk55zFn',
#   'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yLdNVWF3Srea0uzk55zFn',
#   'duration_ms': 200455,
#   'time_signature': 4}]

# %%
example_song[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %% [markdown]
# >I will declare all the list I want to be able to create the datamart. I need a list with songs ID to get the audio features

# %%
# 🏭 Create a funtion to download the information I need 
def tracks_features(playlist_id):
    #Clean all variables
    song_id=[]
    #song_duration=[]
    song_name=[]
    song_popularity=[]
    song_danceability=[]
    song_energy=[]
    song_key=[]
    song_loudness=[]
    song_mode=[]
    song_speechiness=[]
    song_acousticness=[]
    song_instrumentalness=[]
    song_liveness=[]
    song_valence=[]
    song_tempo=[]
    song_type=[]
    song_id=[]
    song_duration_ms=[]

    #We get the playlist elements
    results = sp.user_playlist_tracks("spotify", playlist_id)
    songs = results['items']

    while results['next']:
        results = sp.next(results)
        songs.extend(results['items'])
   
    #loop to get features and info for songs.
    print(len(songs))
    songs=songs[:30]
    print("after",len(songs))
    for song in songs:
        song_id.append(song['track']['id']) #Track id
        song_name.append(song['track']['name']) #Track name
        song_popularity.append(song['track']['popularity']) #Track popularity
    
    dtc_song_id={'song_id':song_id}
    df_song_id =pd.DataFrame.from_dict(dtc_song_id)
    dtc_song_name={'song_name':song_name}
    df_song_name =pd.DataFrame.from_dict(dtc_song_name)
    dtc_song_popularity={'song_popularity':song_popularity}
    df_song_popularity =pd.DataFrame.from_dict(dtc_song_popularity)
    
    #I do it this way to avoid calling the function many times. one per song  
    songs_details=sp.audio_features(tracks=song_id) #get track features
    
    #Create a dataframe with the song features
    df = pd.DataFrame(songs_details)
    
    #Append tracks basic information
    df = pd.concat([df,df_song_name,df_song_popularity],axis=1)
    df.reset_index(drop=True)
    
    #Add the songs to the existing dataframe
    #data=pd.concat([df,data,axis=1)
    #data.reset_index(drop=True)
    
    return df

# %%
song_id=[]
#song_duration=[]
song_name=[]
song_popularity=[]
song_danceability=[]
song_energy=[]
song_key=[]
song_loudness=[]
song_mode=[]
song_speechiness=[]
song_acousticness=[]
song_instrumentalness=[]
song_liveness=[]
song_valence=[]
song_tempo=[]
song_type=[]
song_id=[]
song_duration_ms=[]
#No artist is too complicated and I don´t need it for the model
rawdata = []
new_raw_data=[]

rawdata=tracks_features('3sKSLGn6P4YYtSsMOHOl16')
#Add the songs to the existing dataframe
#data=pd.concat([df,data,axis=1)
#data.reset_index(drop=True)
print(rawdata.shape)
time.sleep(30)
new_raw_data=tracks_features('3PcJZo1iskCo3PdkO0J3ry')
new_raw_data.shape
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
rawdata.shape
time.sleep(30)
new_raw_data=tracks_features('0D59RrFTTaX8KkGARSpASM')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('2GUmJzCpLXzSniGZLsEGjw')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('0euFzlzQWPOqOGbaUMc9Sx')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=new_raw_data=tracks_features('7v1N9ktOI519lEwNqaLCSO')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('2WkH13t7fY6rxRBVQUhliK')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('6tq1Aw8wQtgPxT1VMKj7Pp')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('23JcTLDVX0EN4Z9oq8aNLL')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('6WzYOMvPiHkh9Ae6PVjGdV')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('2h1vy7QPvXH60hPG2ian71')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('7Bkr45VmDQI7AXfvw4YE44')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('0l3u7fBlwyADiN5BtmuEms')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('37ig1KXb3ldtb35yR1NSHC')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)
time.sleep(30)
new_raw_data=tracks_features('2bqvEySRcyOgSGppb8DsJS')
rawdata=pd.concat([rawdata,new_raw_data],axis=0)
rawdata.reset_index(drop=True)

#rawdata.info()
# Out:
# 30
# after 30
# (30, 20)
# 20
# after 20
# 21
# after 21
# 42
# after 30
# 14
# after 14
# 40
# after 30
# 44
# after 30
# 21
# after 21
# 8
# after 8
# 40
# after 30
# 28
# after 28
# 839
# after 30
# 66
# after 30
# 14
# after 14
# 136
# after 30
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.707   0.681    0    -4.325     1       0.0668       0.06320
# 1           0.778   0.632    2    -5.600     0       0.0493       0.27400
# 2           0.660   0.689    4    -2.671     0       0.0337       0.08840
# 3           0.730   0.704    9    -7.040     1       0.0698       0.04170
# 4           0.647   0.728    2    -5.262     1       0.1600       0.05790
# ..            ...     ...  ...       ...   ...          ...           ...
# 361         0.702   0.784    0    -8.484     1       0.0349       0.14400
# 362         0.705   0.948   11    -3.357     0       0.1020       0.10700
# ...

# %%
len(song_id)
# Out:
# 0

# %%
len(song_id)
# Out:
# 0

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 366 entries, 0 to 29
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      366 non-null    float64
#  1   energy            366 non-null    float64
#  2   key               366 non-null    int64
#  3   loudness          366 non-null    float64
#  4   mode              366 non-null    int64
#  5   speechiness       366 non-null    float64
#  6   acousticness      366 non-null    float64
#  7   instrumentalness  366 non-null    float64
#  8   liveness          366 non-null    float64
#  9   valence           366 non-null    float64
#  10  tempo             366 non-null    float64
#  11  type              366 non-null    object
#  12  id                366 non-null    object
#  13  uri               366 non-null    object
#  14  track_href        366 non-null    object
#  15  analysis_url      366 non-null    object
# ...

# %%
#Deleting duplicates in case the song is twice
rawdata=rawdata.drop_duplicates()

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352 entries, 0 to 29
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      352 non-null    float64
#  1   energy            352 non-null    float64
#  2   key               352 non-null    int64
#  3   loudness          352 non-null    float64
#  4   mode              352 non-null    int64
#  5   speechiness       352 non-null    float64
#  6   acousticness      352 non-null    float64
#  7   instrumentalness  352 non-null    float64
#  8   liveness          352 non-null    float64
#  9   valence           352 non-null    float64
#  10  tempo             352 non-null    float64
#  11  type              352 non-null    object
#  12  id                352 non-null    object
#  13  uri               352 non-null    object
#  14  track_href        352 non-null    object
#  15  analysis_url      352 non-null    object
# ...

# %%
#I am happy with the result and here is the dataset as a csv.
rawdata.to_csv('Spotify_raw_data.csv', index=False)
