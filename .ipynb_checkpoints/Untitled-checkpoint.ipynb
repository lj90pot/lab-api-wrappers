# %% [markdown]
# # Lab api wrappers

# %%
#!pip install spotipy
# Out:
# Collecting spotipy
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\luisj\anaconda3\lib\site-packages)
#   Downloading spotipy-2.23.0-py3-none-any.whl (29 kB)
# Collecting redis>=3.5.3
#   Downloading redis-4.6.0-py3-none-any.whl (241 kB)
#      -------------------------------------- 241.1/241.1 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.25.0 in c:\users\luisj\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\luisj\anaconda3\lib\site-packages (from spotipy) (1.26.14)
# Requirement already satisfied: six>=1.15.0 in c:\users\luisj\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Collecting async-timeout>=4.0.2
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\luisj\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luisj\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luisj\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Installing collected packages: async-timeout, redis, spotipy
# Successfully installed async-timeout-4.0.2 redis-4.6.0 spotipy-2.23.0

# %%
# 📚 Import libraries
import pprint #Thanks to my ISI <3
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# Search for an artist

# %% [markdown]
# <div class="alert alert-block alert-info"> <b>NOTE</b> Used only to test how is working. For solution please scroll down </div>

# %%
#Trying seach for an artist
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="ab2abec36e6d42faa859d91cb844ca37",
                                                           client_secret="d07e0208deb5443b9f5195b52a09b790"))

results = sp.search(q='Britney Spears', limit=1, type='artist')  ### type!
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Britney+Spears&type=artist&offset=0&limit=1',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#     'followers': {'href': None, 'total': 12446874},
#     'genres': ['dance pop', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#     'id': '26dSoYclwsYLMAKD3tpOr4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb4e7e6ded87a4e0f65b5afcec',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051744e7e6ded87a4e0f65b5afcec',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1784e7e6ded87a4e0f65b5afcec',
#       'width': 160}],
#     'name': 'Britney Spears',
#     'popularity': 80,
#     'type': 'artist',
#     'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Britney+Spears&type=artist&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 76}}

# %%
results = sp.search(q='Rosalia', limit=1, type='artist')  ### type!
results
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Rosalia&type=artist&offset=0&limit=1',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#     'followers': {'href': None, 'total': 7443306},
#     'genres': ['pop', 'r&b en espanol'],
#     'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#     'id': '7ltDVBr6mKbRvohxheJ9h1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebd7bb678bef6d2f26110cae49',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174d7bb678bef6d2f26110cae49',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178d7bb678bef6d2f26110cae49',
#       'width': 160}],
#     'name': 'ROSALÍA',
#     'popularity': 84,
#     'type': 'artist',
#     'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Rosalia&type=artist&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 42}}

# %%
#Link to my playlist just here copied to not forget it 
3sKSLGn6P4YYtSsMOHOl16?si=ad2c6d1a541f4ee8

# %%
results.keys()
# Out:
# dict_keys(['artists'])

# %%
playlist = sp.user_playlist_tracks("spotify", "3sKSLGn6P4YYtSsMOHOl16")
playlist#.keys() # Let's look at items and total:
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3sKSLGn6P4YYtSsMOHOl16/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-01-22T15:28:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#      'href': 'https://api.spotify.com/v1/albums/7I0tjwFtxUwBC1vgyeMAax',
#      'id': '7I0tjwFtxUwBC1vgyeMAax',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f429549123dbe8552764ba1d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f429549123dbe8552764ba1d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f429549123dbe8552764ba1d',
#        'width': 64}],
#      'name': 'Flowers',
#      'release_date': '2023-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7I0tjwFtxUwBC1vgyeMAax'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 200454,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12209777'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#     'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#     'id': '0yLdNVWF3Srea0uzk55zFn',
#     'is_local': False,
#     'name': 'Flowers',
#     'popularity': 97,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9fbe346e805ed219204f53324f94557ab557b6d3?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-22T15:28:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#        'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#        'id': '716NhGYqD1jl2wI1Qkgq36',
#        'name': 'Bizarrap',
#        'type': 'artist',
#        'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#        'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#        'id': '0EmeFodog0BfCgMzAIvKQp',
#        'name': 'Shakira',
#        'type': 'artist',
#        'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1gi2iwr1l8IUyHYHxi01pg'},
#      'href': 'https://api.spotify.com/v1/albums/1gi2iwr1l8IUyHYHxi01pg',
#      'id': '1gi2iwr1l8IUyHYHxi01pg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732b6d78c5a3f6247aa997b812',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022b6d78c5a3f6247aa997b812',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512b6d78c5a3f6247aa997b812',
#        'width': 64}],
#      'name': 'Shakira: Bzrp Music Sessions, Vol. 53',
#      'release_date': '2023-01-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1gi2iwr1l8IUyHYHxi01pg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#       'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#       'id': '716NhGYqD1jl2wI1Qkgq36',
#       'name': 'Bizarrap',
#       'type': 'artist',
#       'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 214945,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UYB282301031'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4nrPB8O7Y7wsOCJdgXkthe'},
#     'href': 'https://api.spotify.com/v1/tracks/4nrPB8O7Y7wsOCJdgXkthe',
#     'id': '4nrPB8O7Y7wsOCJdgXkthe',
#     'is_local': False,
#     'name': 'Shakira: Bzrp Music Sessions, Vol. 53',
#     'popularity': 93,
#     'preview_url': 'https://p.scdn.co/mp3-preview/64e90f49942deb7dd92610fb8ef64b30524e6009?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4nrPB8O7Y7wsOCJdgXkthe'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-22T15:42:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CwfuxIqcltXDGjfZsMd9A'},
#        'href': 'https://api.spotify.com/v1/artists/6CwfuxIqcltXDGjfZsMd9A',
#        'id': '6CwfuxIqcltXDGjfZsMd9A',
#        'name': 'MARINA',
#        'type': 'artist',
#        'uri': 'spotify:artist:6CwfuxIqcltXDGjfZsMd9A'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/49kf7gWWtReFwPcCNsvyUf'},
#      'href': 'https://api.spotify.com/v1/albums/49kf7gWWtReFwPcCNsvyUf',
#      'id': '49kf7gWWtReFwPcCNsvyUf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273203e4c6a048df02a21cdd813',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02203e4c6a048df02a21cdd813',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851203e4c6a048df02a21cdd813',
#        'width': 64}],
#      'name': 'Electra Heart (Deluxe)',
#      'release_date': '2012-04-30',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:49kf7gWWtReFwPcCNsvyUf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CwfuxIqcltXDGjfZsMd9A'},
#       'href': 'https://api.spotify.com/v1/artists/6CwfuxIqcltXDGjfZsMd9A',
#       'id': '6CwfuxIqcltXDGjfZsMd9A',
#       'name': 'MARINA',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CwfuxIqcltXDGjfZsMd9A'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'HT',
#      'JM',
#      'LS',
#      'LR',
#      'MW',
#      'ML',
#      'FM',
#      'NA',
#      'NE',
#      'PG',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TT',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 221075,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBFFS1200009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4sOX1nhpKwFWPvoMMExi3q'},
#     'href': 'https://api.spotify.com/v1/tracks/4sOX1nhpKwFWPvoMMExi3q',
#     'id': '4sOX1nhpKwFWPvoMMExi3q',
#     'is_local': False,
#     'name': 'Primadonna',
#     'popularity': 75,
#     'preview_url': 'https://p.scdn.co/mp3-preview/348095fbb0f83352a3da25bcdcc45a206c83a963?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4sOX1nhpKwFWPvoMMExi3q'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-22T15:29:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DOERbtkx9aTLvWzZSB0qx'},
#        'href': 'https://api.spotify.com/v1/artists/7DOERbtkx9aTLvWzZSB0qx',
#        'id': '7DOERbtkx9aTLvWzZSB0qx',
#        'name': 'Rigoberta Bandini',
#        'type': 'artist',
#        'uri': 'spotify:artist:7DOERbtkx9aTLvWzZSB0qx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7f3vr9igj7vDgo3SBIN8Fv'},
#      'href': 'https://api.spotify.com/v1/albums/7f3vr9igj7vDgo3SBIN8Fv',
#      'id': '7f3vr9igj7vDgo3SBIN8Fv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c0e604aadf88ecaca541dbd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c0e604aadf88ecaca541dbd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c0e604aadf88ecaca541dbd',
#        'width': 64}],
#      'name': 'La Emperatriz',
#      'release_date': '2022-10-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7f3vr9igj7vDgo3SBIN8Fv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DOERbtkx9aTLvWzZSB0qx'},
#       'href': 'https://api.spotify.com/v1/artists/7DOERbtkx9aTLvWzZSB0qx',
#       'id': '7DOERbtkx9aTLvWzZSB0qx',
#       'name': 'Rigoberta Bandini',
#       'type': 'artist',
#       'uri': 'spotify:artist:7DOERbtkx9aTLvWzZSB0qx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 217800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4TW2110992'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6g4ZPyb7WdvC67X160oKmb'},
#     'href': 'https://api.spotify.com/v1/tracks/6g4ZPyb7WdvC67X160oKmb',
#     'id': '6g4ZPyb7WdvC67X160oKmb',
#     'is_local': False,
#     'name': 'Perra',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6436e2b0bbacaae5882b1f1530388a7b404ba8bf?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6g4ZPyb7WdvC67X160oKmb'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-22T15:28:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DOERbtkx9aTLvWzZSB0qx'},
#        'href': 'https://api.spotify.com/v1/artists/7DOERbtkx9aTLvWzZSB0qx',
#        'id': '7DOERbtkx9aTLvWzZSB0qx',
#        'name': 'Rigoberta Bandini',
#        'type': 'artist',
#        'uri': 'spotify:artist:7DOERbtkx9aTLvWzZSB0qx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7f3vr9igj7vDgo3SBIN8Fv'},
#      'href': 'https://api.spotify.com/v1/albums/7f3vr9igj7vDgo3SBIN8Fv',
#      'id': '7f3vr9igj7vDgo3SBIN8Fv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c0e604aadf88ecaca541dbd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c0e604aadf88ecaca541dbd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c0e604aadf88ecaca541dbd',
#        'width': 64}],
#      'name': 'La Emperatriz',
#      'release_date': '2022-10-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7f3vr9igj7vDgo3SBIN8Fv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DOERbtkx9aTLvWzZSB0qx'},
#       'href': 'https://api.spotify.com/v1/artists/7DOERbtkx9aTLvWzZSB0qx',
#       'id': '7DOERbtkx9aTLvWzZSB0qx',
#       'name': 'Rigoberta Bandini',
#       'type': 'artist',
#       'uri': 'spotify:artist:7DOERbtkx9aTLvWzZSB0qx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1WLEfsQjvgtFSGkrHonzFX'},
#       'href': 'https://api.spotify.com/v1/artists/1WLEfsQjvgtFSGkrHonzFX',
#       'id': '1WLEfsQjvgtFSGkrHonzFX',
#       'name': 'Amaia',
#       'type': 'artist',
#       'uri': 'spotify:artist:1WLEfsQjvgtFSGkrHonzFX'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 209573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM6N22265432'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/61EzFxAX2KM66vmcc2CO1k'},
#     'href': 'https://api.spotify.com/v1/tracks/61EzFxAX2KM66vmcc2CO1k',
#     'id': '61EzFxAX2KM66vmcc2CO1k',
#     'is_local': False,
#     'name': 'Así Bailaba',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/faac04a5883094a426e94f015ef24543b456de30?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:61EzFxAX2KM66vmcc2CO1k'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-22T15:29:12Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DOERbtkx9aTLvWzZSB0qx'},
#        'href': 'https://api.spotify.com/v1/artists/7DOERbtkx9aTLvWzZSB0qx',
#        'id': '7DOERbtkx9aTLvWzZSB0qx',
#        'name': 'Rigoberta Bandini',
#        'type': 'artist',
#        'uri': 'spotify:artist:7DOERbtkx9aTLvWzZSB0qx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7f3vr9igj7vDgo3SBIN8Fv'},
#      'href': 'https://api.spotify.com/v1/albums/7f3vr9igj7vDgo3SBIN8Fv',
#      'id': '7f3vr9igj7vDgo3SBIN8Fv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c0e604aadf88ecaca541dbd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c0e604aadf88ecaca541dbd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c0e604aadf88ecaca541dbd',
#        'width': 64}],
#      'name': 'La Emperatriz',
#      'release_date': '2022-10-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:7f3vr9igj7vDgo3SBIN8Fv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7DOERbtkx9aTLvWzZSB0qx'},
#       'href': 'https://api.spotify.com/v1/artists/7DOERbtkx9aTLvWzZSB0qx',
#       'id': '7DOERbtkx9aTLvWzZSB0qx',
#       'name': 'Rigoberta Bandini',
#       'type': 'artist',
#       'uri': 'spotify:artist:7DOERbtkx9aTLvWzZSB0qx'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 329000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ESA012019842'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0xSbYIN12FB1giZI5ymCdz'},
#     'href': 'https://api.spotify.com/v1/tracks/0xSbYIN12FB1giZI5ymCdz',
#     'id': '0xSbYIN12FB1giZI5ymCdz',
#     'is_local': False,
#     'name': 'Too Many Drugs',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1e52f339c92df87fd02e761d7fdaa16ed63b8f2b?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0xSbYIN12FB1giZI5ymCdz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-01-22T15:29:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1b6ctmaHGrw89ZUmm0nGXq'},
#        'href': 'https://api.spotify.com/v1/artists/1b6ctmaHGrw89ZUmm0nGXq',
#        'id': '1b6ctmaHGrw89ZUmm0nGXq',
#        'name': 'María Peláe',
#        'type': 'artist',
#        'uri': 'spotify:artist:1b6ctmaHGrw89ZUmm0nGXq'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3cAE3TZQGJELs8gxtFd1eL'},
#      'href': 'https://api.spotify.com/v1/albums/3cAE3TZQGJELs8gxtFd1eL',
#      'id': '3cAE3TZQGJELs8gxtFd1eL',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27386d392603bdd91236e3c36dc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0286d392603bdd91236e3c36dc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485186d392603bdd91236e3c36dc',
#        'width': 64}],
#      'name': 'La Folcrónica',
#      'release_date': '2022-03-11',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3cAE3TZQGJELs8gxtFd1eL'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1b6ctmaHGrw89ZUmm0nGXq'},
#       'href': 'https://api.spotify.com/v1/artists/1b6ctmaHGrw89ZUmm0nGXq',
#       'id': '1b6ctmaHGrw89ZUmm0nGXq',
#       'name': 'María Peláe',
#       'type': 'artist',
#       'uri': 'spotify:artist:1b6ctmaHGrw89ZUmm0nGXq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 209106,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHZ31975917'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Qz2w5X6i668NCl1waBzGG'},
#     'href': 'https://api.spotify.com/v1/tracks/1Qz2w5X6i668NCl1waBzGG',
#     'id': '1Qz2w5X6i668NCl1waBzGG',
#     'is_local': False,
#     'name': 'La Niña',
#     'popularity': 49,
# ...
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 406584,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BE4JP2292009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/21WIoAisDlLyEsRAZX35CT'},
#     'href': 'https://api.spotify.com/v1/tracks/21WIoAisDlLyEsRAZX35CT',
#     'id': '21WIoAisDlLyEsRAZX35CT',
#     'is_local': False,
#     'name': 'Reflection',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/db730f408e33846f95a861cf5bf5da72dcabba02?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:21WIoAisDlLyEsRAZX35CT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-05-08T21:42:07Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/679xKCdF1dBRH0gGgZfcCC'},
#        'href': 'https://api.spotify.com/v1/artists/679xKCdF1dBRH0gGgZfcCC',
#        'id': '679xKCdF1dBRH0gGgZfcCC',
#        'name': 'Kaspar',
#        'type': 'artist',
#        'uri': 'spotify:artist:679xKCdF1dBRH0gGgZfcCC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2slp7A7kwstJKJrg6hTWpu'},
#      'href': 'https://api.spotify.com/v1/albums/2slp7A7kwstJKJrg6hTWpu',
#      'id': '2slp7A7kwstJKJrg6hTWpu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273aacac434f062bc691687e944',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02aacac434f062bc691687e944',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851aacac434f062bc691687e944',
#        'width': 64}],
#      'name': 'Always Believed',
#      'release_date': '2023-05-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2slp7A7kwstJKJrg6hTWpu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/679xKCdF1dBRH0gGgZfcCC'},
#       'href': 'https://api.spotify.com/v1/artists/679xKCdF1dBRH0gGgZfcCC',
#       'id': '679xKCdF1dBRH0gGgZfcCC',
#       'name': 'Kaspar',
#       'type': 'artist',
#       'uri': 'spotify:artist:679xKCdF1dBRH0gGgZfcCC'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 350075,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEPI82306454'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3gaIIBUh8npzwh1ObuEVdM'},
#     'href': 'https://api.spotify.com/v1/tracks/3gaIIBUh8npzwh1ObuEVdM',
#     'id': '3gaIIBUh8npzwh1ObuEVdM',
#     'is_local': False,
#     'name': 'Always Believed',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e0668494408f3dae35dc601b20bc68d147260129?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3gaIIBUh8npzwh1ObuEVdM'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-05-08T21:42:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#     'href': 'https://api.spotify.com/v1/users/luisja90',
#     'id': 'luisja90',
#     'type': 'user',
#     'uri': 'spotify:user:luisja90'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rxmj7vNEofe96g84qMWoV'},
#        'href': 'https://api.spotify.com/v1/artists/6rxmj7vNEofe96g84qMWoV',
#        'id': '6rxmj7vNEofe96g84qMWoV',
#        'name': 'Jay Lumen',
#        'type': 'artist',
#        'uri': 'spotify:artist:6rxmj7vNEofe96g84qMWoV'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CZVDDNWqniSK1aUYy8MGY'},
#      'href': 'https://api.spotify.com/v1/albums/1CZVDDNWqniSK1aUYy8MGY',
#      'id': '1CZVDDNWqniSK1aUYy8MGY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d26d08df827fe60102a8609',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d26d08df827fe60102a8609',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d26d08df827fe60102a8609',
#        'width': 64}],
#      'name': 'Spacewalk',
#      'release_date': '2023-04-14',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1CZVDDNWqniSK1aUYy8MGY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rxmj7vNEofe96g84qMWoV'},
#       'href': 'https://api.spotify.com/v1/artists/6rxmj7vNEofe96g84qMWoV',
#       'id': '6rxmj7vNEofe96g84qMWoV',
#       'name': 'Jay Lumen',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rxmj7vNEofe96g84qMWoV'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 416000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEH742307233'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Vn9JwANzvfh4g3yLVCbqL'},
#     'href': 'https://api.spotify.com/v1/tracks/2Vn9JwANzvfh4g3yLVCbqL',
#     'id': '2Vn9JwANzvfh4g3yLVCbqL',
#     'is_local': False,
#     'name': 'Spacewalk',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/563d31ee2c2de77bb6914decb2ea423bd4c33b08?cid=ab2abec36e6d42faa859d91cb844ca37',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2Vn9JwANzvfh4g3yLVCbqL'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 30}

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3sKSLGn6P4YYtSsMOHOl16/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-01-22T15:28:12Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#                          'href': 'https://api.spotify.com/v1/users/luisja90',
#                          'id': 'luisja90',
#                          'type': 'user',
#                          'uri': 'spotify:user:luisja90'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                              'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                              'id': '5YGY8feqx7naU7z4HrwZM6',
#                                              'name': 'Miley Cyrus',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'ET',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#                                 'href': 'https://api.spotify.com/v1/albums/7I0tjwFtxUwBC1vgyeMAax',
#                                 'id': '7I0tjwFtxUwBC1vgyeMAax',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273f429549123dbe8552764ba1d',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02f429549123dbe8552764ba1d',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851f429549123dbe8552764ba1d',
#                                             'width': 64}],
#                                 'name': 'Flowers',
#                                 'release_date': '2023-01-13',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:7I0tjwFtxUwBC1vgyeMAax'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                    'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                    'id': '5YGY8feqx7naU7z4HrwZM6',
#                                    'name': 'Miley Cyrus',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 200454,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USSM12209777'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#                       'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#                       'id': '0yLdNVWF3Srea0uzk55zFn',
#                       'is_local': False,
#                       'name': 'Flowers',
#                       'popularity': 97,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/9fbe346e805ed219204f53324f94557ab557b6d3?cid=ab2abec36e6d42faa859d91cb844ca37',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-01-22T15:28:22Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#                          'href': 'https://api.spotify.com/v1/users/luisja90',
#                          'id': 'luisja90',
#                          'type': 'user',
#                          'uri': 'spotify:user:luisja90'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#                                              'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#                                              'id': '716NhGYqD1jl2wI1Qkgq36',
#                                              'name': 'Bizarrap',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#                                             {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#                                              'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#                                              'id': '0EmeFodog0BfCgMzAIvKQp',
#                                              'name': 'Shakira',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#                                 'available_markets': ['AD',
#                                                       'AE',
#                                                       'AG',
#                                                       'AL',
#                                                       'AM',
#                                                       'AO',
#                                                       'AR',
#                                                       'AT',
#                                                       'AU',
#                                                       'AZ',
#                                                       'BA',
#                                                       'BB',
#                                                       'BD',
#                                                       'BE',
#                                                       'BF',
#                                                       'BG',
#                                                       'BH',
#                                                       'BI',
#                                                       'BJ',
#                                                       'BN',
#                                                       'BO',
#                                                       'BR',
#                                                       'BS',
#                                                       'BT',
#                                                       'BW',
#                                                       'BY',
#                                                       'BZ',
#                                                       'CA',
#                                                       'CD',
#                                                       'CG',
#                                                       'CH',
#                                                       'CI',
#                                                       'CL',
#                                                       'CM',
#                                                       'CO',
#                                                       'CR',
#                                                       'CV',
#                                                       'CW',
#                                                       'CY',
#                                                       'CZ',
#                                                       'DE',
#                                                       'DJ',
#                                                       'DK',
#                                                       'DM',
#                                                       'DO',
#                                                       'DZ',
#                                                       'EC',
#                                                       'EE',
#                                                       'EG',
#                                                       'ES',
#                                                       'ET',
#                                                       'FI',
#                                                       'FJ',
#                                                       'FM',
#                                                       'FR',
#                                                       'GA',
#                                                       'GB',
#                                                       'GD',
#                                                       'GE',
#                                                       'GH',
#                                                       'GM',
#                                                       'GN',
#                                                       'GQ',
#                                                       'GR',
#                                                       'GT',
#                                                       'GW',
#                                                       'GY',
#                                                       'HK',
#                                                       'HN',
#                                                       'HR',
#                                                       'HT',
#                                                       'HU',
#                                                       'ID',
#                                                       'IE',
#                                                       'IL',
#                                                       'IN',
#                                                       'IQ',
#                                                       'IS',
#                                                       'IT',
#                                                       'JM',
#                                                       'JO',
#                                                       'JP',
#                                                       'KE',
#                                                       'KG',
#                                                       'KH',
#                                                       'KI',
#                                                       'KM',
#                                                       'KN',
#                                                       'KR',
#                                                       'KW',
#                                                       'KZ',
#                                                       'LA',
#                                                       'LB',
#                                                       'LC',
#                                                       'LI',
#                                                       'LK',
#                                                       'LR',
#                                                       'LS',
#                                                       'LT',
#                                                       'LU',
#                                                       'LV',
#                                                       'LY',
#                                                       'MA',
#                                                       'MC',
#                                                       'MD',
#                                                       'ME',
#                                                       'MG',
#                                                       'MH',
#                                                       'MK',
#                                                       'ML',
#                                                       'MN',
#                                                       'MO',
#                                                       'MR',
#                                                       'MT',
#                                                       'MU',
#                                                       'MV',
#                                                       'MW',
#                                                       'MX',
#                                                       'MY',
#                                                       'MZ',
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1gi2iwr1l8IUyHYHxi01pg'},
#                                 'href': 'https://api.spotify.com/v1/albums/1gi2iwr1l8IUyHYHxi01pg',
#                                 'id': '1gi2iwr1l8IUyHYHxi01pg',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732b6d78c5a3f6247aa997b812',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022b6d78c5a3f6247aa997b812',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512b6d78c5a3f6247aa997b812',
#                                             'width': 64}],
#                                 'name': 'Shakira: Bzrp Music Sessions, Vol. 53',
#                                 'release_date': '2023-01-11',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1gi2iwr1l8IUyHYHxi01pg'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/716NhGYqD1jl2wI1Qkgq36'},
#                                    'href': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36',
#                                    'id': '716NhGYqD1jl2wI1Qkgq36',
#                                    'name': 'Bizarrap',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:716NhGYqD1jl2wI1Qkgq36'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#                                    'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#                                    'id': '0EmeFodog0BfCgMzAIvKQp',
#                                    'name': 'Shakira',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
# ...
#                                                       'NA',
#                                                       'NE',
#                                                       'NG',
#                                                       'NI',
#                                                       'NL',
#                                                       'NO',
#                                                       'NP',
#                                                       'NR',
#                                                       'NZ',
#                                                       'OM',
#                                                       'PA',
#                                                       'PE',
#                                                       'PG',
#                                                       'PH',
#                                                       'PK',
#                                                       'PL',
#                                                       'PS',
#                                                       'PT',
#                                                       'PW',
#                                                       'PY',
#                                                       'QA',
#                                                       'RO',
#                                                       'RS',
#                                                       'RW',
#                                                       'SA',
#                                                       'SB',
#                                                       'SC',
#                                                       'SE',
#                                                       'SG',
#                                                       'SI',
#                                                       'SK',
#                                                       'SL',
#                                                       'SM',
#                                                       'SN',
#                                                       'SR',
#                                                       'ST',
#                                                       'SV',
#                                                       'SZ',
#                                                       'TD',
#                                                       'TG',
#                                                       'TH',
#                                                       'TJ',
#                                                       'TL',
#                                                       'TN',
#                                                       'TO',
#                                                       'TR',
#                                                       'TT',
#                                                       'TV',
#                                                       'TW',
#                                                       'TZ',
#                                                       'UA',
#                                                       'UG',
#                                                       'US',
#                                                       'UY',
#                                                       'UZ',
#                                                       'VC',
#                                                       'VE',
#                                                       'VN',
#                                                       'VU',
#                                                       'WS',
#                                                       'XK',
#                                                       'ZA',
#                                                       'ZM',
#                                                       'ZW'],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1CZVDDNWqniSK1aUYy8MGY'},
#                                 'href': 'https://api.spotify.com/v1/albums/1CZVDDNWqniSK1aUYy8MGY',
#                                 'id': '1CZVDDNWqniSK1aUYy8MGY',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2735d26d08df827fe60102a8609',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e025d26d08df827fe60102a8609',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048515d26d08df827fe60102a8609',
#                                             'width': 64}],
#                                 'name': 'Spacewalk',
#                                 'release_date': '2023-04-14',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 2,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1CZVDDNWqniSK1aUYy8MGY'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rxmj7vNEofe96g84qMWoV'},
#                                    'href': 'https://api.spotify.com/v1/artists/6rxmj7vNEofe96g84qMWoV',
#                                    'id': '6rxmj7vNEofe96g84qMWoV',
#                                    'name': 'Jay Lumen',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:6rxmj7vNEofe96g84qMWoV'}],
#                       'available_markets': ['AR',
#                                             'AU',
#                                             'AT',
#                                             'BE',
#                                             'BO',
#                                             'BR',
#                                             'BG',
#                                             'CA',
#                                             'CL',
#                                             'CO',
#                                             'CR',
#                                             'CY',
#                                             'CZ',
#                                             'DK',
#                                             'DO',
#                                             'DE',
#                                             'EC',
#                                             'EE',
#                                             'SV',
#                                             'FI',
#                                             'FR',
#                                             'GR',
#                                             'GT',
#                                             'HN',
#                                             'HK',
#                                             'HU',
#                                             'IS',
#                                             'IE',
#                                             'IT',
#                                             'LV',
#                                             'LT',
#                                             'LU',
#                                             'MY',
#                                             'MT',
#                                             'MX',
#                                             'NL',
#                                             'NZ',
#                                             'NI',
#                                             'NO',
#                                             'PA',
#                                             'PY',
#                                             'PE',
#                                             'PH',
#                                             'PL',
#                                             'PT',
#                                             'SG',
#                                             'SK',
#                                             'ES',
#                                             'SE',
#                                             'CH',
#                                             'TW',
#                                             'TR',
#                                             'UY',
#                                             'US',
#                                             'GB',
#                                             'AD',
#                                             'LI',
#                                             'MC',
#                                             'ID',
#                                             'JP',
#                                             'TH',
#                                             'VN',
#                                             'RO',
#                                             'IL',
#                                             'ZA',
#                                             'SA',
#                                             'AE',
#                                             'BH',
#                                             'QA',
#                                             'OM',
#                                             'KW',
#                                             'EG',
#                                             'MA',
#                                             'DZ',
#                                             'TN',
#                                             'LB',
#                                             'JO',
#                                             'PS',
#                                             'IN',
#                                             'BY',
#                                             'KZ',
#                                             'MD',
#                                             'UA',
#                                             'AL',
#                                             'BA',
#                                             'HR',
#                                             'ME',
#                                             'MK',
#                                             'RS',
#                                             'SI',
#                                             'KR',
#                                             'BD',
#                                             'PK',
#                                             'LK',
#                                             'GH',
#                                             'KE',
#                                             'NG',
#                                             'TZ',
#                                             'UG',
#                                             'AG',
#                                             'AM',
#                                             'BS',
#                                             'BB',
#                                             'BZ',
#                                             'BT',
#                                             'BW',
#                                             'BF',
#                                             'CV',
#                                             'CW',
#                                             'DM',
#                                             'FJ',
#                                             'GM',
#                                             'GE',
#                                             'GD',
#                                             'GW',
#                                             'GY',
#                                             'HT',
#                                             'JM',
#                                             'KI',
#                                             'LS',
#                                             'LR',
#                                             'MW',
#                                             'MV',
#                                             'ML',
#                                             'MH',
#                                             'FM',
#                                             'NA',
#                                             'NR',
#                                             'NE',
#                                             'PW',
#                                             'PG',
#                                             'WS',
#                                             'SM',
#                                             'ST',
#                                             'SN',
#                                             'SC',
#                                             'SL',
#                                             'SB',
#                                             'KN',
#                                             'LC',
#                                             'VC',
#                                             'SR',
#                                             'TL',
#                                             'TO',
#                                             'TT',
#                                             'TV',
#                                             'VU',
#                                             'AZ',
#                                             'BN',
#                                             'BI',
#                                             'KH',
#                                             'CM',
#                                             'TD',
#                                             'KM',
#                                             'GQ',
#                                             'SZ',
#                                             'GA',
#                                             'GN',
#                                             'KG',
#                                             'LA',
#                                             'MO',
#                                             'MR',
#                                             'MN',
#                                             'NP',
#                                             'RW',
#                                             'TG',
#                                             'UZ',
#                                             'ZW',
#                                             'BJ',
#                                             'MG',
#                                             'MU',
#                                             'MZ',
#                                             'AO',
#                                             'CI',
#                                             'DJ',
#                                             'ZM',
#                                             'CD',
#                                             'CG',
#                                             'IQ',
#                                             'LY',
#                                             'TJ',
#                                             'VE',
#                                             'ET',
#                                             'XK'],
#                       'disc_number': 1,
#                       'duration_ms': 416000,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'DEH742307233'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2Vn9JwANzvfh4g3yLVCbqL'},
#                       'href': 'https://api.spotify.com/v1/tracks/2Vn9JwANzvfh4g3yLVCbqL',
#                       'id': '2Vn9JwANzvfh4g3yLVCbqL',
#                       'is_local': False,
#                       'name': 'Spacewalk',
#                       'popularity': 50,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/563d31ee2c2de77bb6914decb2ea423bd4c33b08?cid=ab2abec36e6d42faa859d91cb844ca37',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:2Vn9JwANzvfh4g3yLVCbqL'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 30}

# %% [markdown]
# Checking all the options to see what they do or contains

# %%
playlist["total"]
# Out:
# 30

# %%
playlist["href"]
# Out:
# 'https://api.spotify.com/v1/playlists/3sKSLGn6P4YYtSsMOHOl16/tracks?offset=0&limit=100&additional_types=track'

# %%
len(playlist["items"])
# Out:
# 30

# %%
playlist["limit"]
# Out:
# 100

# %%
playlist["next"]

# %%
playlist["offset"]
# Out:
# 0

# %%
playlist["previous"]

# %% [markdown]
# I have 30 songs in this playlist and the items are 30 so I can download them

# %%
### OPTION 1
results = sp.user_playlist_tracks("spotify", "3sKSLGn6P4YYtSsMOHOl16")
songs = results['items']

while results['next']:
    results = sp.next(results)
    songs.extend(results['items'])
len(songs)
# Out:
# 30

# %% [markdown]
# The tedious investigation of where the hell the information is
# <div class="alert alert-block alert-info"> <b>NOTE</b> Used only to test how is working. For solution please scroll down </div>

# %%
#- songs[0]['track']['id'] #Track id
#- songs[0]['track']['duration_ms'] #duration
#- songs[0]['track']['name'] #Song name
#- songs[0]['track']['popularity'] #Popularity

# %%
songs[0]
# Out:
# {'added_at': '2023-01-22T15:28:12Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/luisja90'},
#   'href': 'https://api.spotify.com/v1/users/luisja90',
#   'id': 'luisja90',
#   'type': 'user',
#   'uri': 'spotify:user:luisja90'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#      'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#      'id': '5YGY8feqx7naU7z4HrwZM6',
#      'name': 'Miley Cyrus',
#      'type': 'artist',
#      'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'ET',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#    'href': 'https://api.spotify.com/v1/albums/7I0tjwFtxUwBC1vgyeMAax',
#    'id': '7I0tjwFtxUwBC1vgyeMAax',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273f429549123dbe8552764ba1d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02f429549123dbe8552764ba1d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851f429549123dbe8552764ba1d',
#      'width': 64}],
#    'name': 'Flowers',
#    'release_date': '2023-01-13',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7I0tjwFtxUwBC1vgyeMAax'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#     'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#     'id': '5YGY8feqx7naU7z4HrwZM6',
#     'name': 'Miley Cyrus',
#     'type': 'artist',
#     'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 200454,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'USSM12209777'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#   'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#   'id': '0yLdNVWF3Srea0uzk55zFn',
#   'is_local': False,
#   'name': 'Flowers',
#   'popularity': 97,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9fbe346e805ed219204f53324f94557ab557b6d3?cid=ab2abec36e6d42faa859d91cb844ca37',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn'},
#  'video_thumbnail': {'url': None}}

# %%
songs[0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
songs[0].keys()

# %%
songs[0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#     'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#     'id': '5YGY8feqx7naU7z4HrwZM6',
#     'name': 'Miley Cyrus',
#     'type': 'artist',
#     'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7I0tjwFtxUwBC1vgyeMAax'},
#   'href': 'https://api.spotify.com/v1/albums/7I0tjwFtxUwBC1vgyeMAax',
#   'id': '7I0tjwFtxUwBC1vgyeMAax',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f429549123dbe8552764ba1d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f429549123dbe8552764ba1d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f429549123dbe8552764ba1d',
#     'width': 64}],
#   'name': 'Flowers',
#   'release_date': '2023-01-13',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:7I0tjwFtxUwBC1vgyeMAax'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#    'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#    'id': '5YGY8feqx7naU7z4HrwZM6',
#    'name': 'Miley Cyrus',
#    'type': 'artist',
#    'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 200454,
#  'episode': False,
#  'explicit': False,
#  'external_ids': {'isrc': 'USSM12209777'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/0yLdNVWF3Srea0uzk55zFn'},
#  'href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#  'id': '0yLdNVWF3Srea0uzk55zFn',
#  'is_local': False,
#  'name': 'Flowers',
#  'popularity': 97,
#  'preview_url': 'https://p.scdn.co/mp3-preview/9fbe346e805ed219204f53324f94557ab557b6d3?cid=ab2abec36e6d42faa859d91cb844ca37',
#  'track': True,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn'}

# %%
songs[0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'episode', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track', 'track_number', 'type', 'uri'])

# %%
songs[0]['track']['duration_ms'] #duration
# Out:
# 200454

# %%
songs[0]['track']['name']
# Out:
# 'Flowers'

# %%
songs[0]['track']['popularity']
# Out:
# 97

# %%
songs[0]['track']['id']
# Out:
# '0yLdNVWF3Srea0uzk55zFn'

# %%
songs[0]['track']['artists'][0]#['name']
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#  'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#  'id': '5YGY8feqx7naU7z4HrwZM6',
#  'name': 'Miley Cyrus',
#  'type': 'artist',
#  'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}

# %% [markdown]
# How to get track features

# %%
example_song=sp.audio_features(tracks=["0yLdNVWF3Srea0uzk55zFn"])
example_song
# Out:
# [{'danceability': 0.707,
#   'energy': 0.681,
#   'key': 0,
#   'loudness': -4.325,
#   'mode': 1,
#   'speechiness': 0.0668,
#   'acousticness': 0.0632,
#   'instrumentalness': 5.15e-06,
#   'liveness': 0.0322,
#   'valence': 0.646,
#   'tempo': 117.999,
#   'type': 'audio_features',
#   'id': '0yLdNVWF3Srea0uzk55zFn',
#   'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yLdNVWF3Srea0uzk55zFn',
#   'duration_ms': 200455,
#   'time_signature': 4}]

# %%
example_song[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %% [markdown]
# >I will declare all the list I want to be able to create the datamart. I need a list with songs ID to get the audio features

# %%
song_id=[]
#song_duration=[]
song_name=[]
song_popularity=[]
song_danceability=[]
song_energy=[]
song_key=[]
song_loudness=[]
song_mode=[]
song_speechiness=[]
song_acousticness=[]
song_instrumentalness=[]
song_liveness=[]
song_valence=[]
song_tempo=[]
song_type=[]
song_id=[]
song_duration_ms=[]

#loop to get features and info for songs. 
for song in songs:
    song_id.append(song['track']['id']) #Track id
    
#I do it this way to avoid calling the function many times. one per song     
songs_details=sp.audio_features(tracks=song_id)
for song_det in songs_details:
    song_danceability.append(song_det['danceability'])

# %%
len(song_id)
# Out:
# 30

# %%
song_id
# Out:
# ['0yLdNVWF3Srea0uzk55zFn',
#  '4nrPB8O7Y7wsOCJdgXkthe',
#  '4sOX1nhpKwFWPvoMMExi3q',
#  '6g4ZPyb7WdvC67X160oKmb',
#  '61EzFxAX2KM66vmcc2CO1k',
#  '0xSbYIN12FB1giZI5ymCdz',
#  '1Qz2w5X6i668NCl1waBzGG',
#  '5m4QyDRlKdQmiX1mFnQQij',
#  '0ccNNtxwKNHzzzGI4hIb2z',
#  '6LsYwZwT0s5w51Z8Y8Fy7T',
#  '4KcZS9aLgl2AZuRQl5E3c6',
#  '2oRtscLLwdLMiDpRoQOSWW',
#  '2SiAcexM2p1yX6joESbehd',
#  '0BIotAHhS0t5TUCLfVEZBo',
#  '20CozgjF6bshBw8cLhN23B',
#  '2ERn9fVsix3AyuVv7UN6RC',
#  '5qDzKUTHCUiKhewBa9STsE',
#  '2toCf2FDbTIdWriPI6kcsY',
#  '414rOgwyJUcY49sGW5CsZy',
#  '5ZduaRci3iNUiDfJbBfAaf',
#  '7xaqxUl08zOg0YNUHokQpq',
#  '2hP1NjQ0P5B0B5yB2IMf6q',
#  '3BKD1PwArikchz2Zrlp1qi',
#  '5aY2pfyGLxBpuI4TruqmQx',
#  '1mWbB1bGjvdZR3vFtaT2gL',
#  '0UYjebmO93HnkBaac49FMu',
#  '3UCY8UXQRBgbNlbT4cW2Cq',
#  '21WIoAisDlLyEsRAZX35CT',
#  '3gaIIBUh8npzwh1ObuEVdM',
#  '2Vn9JwANzvfh4g3yLVCbqL']

# %%
example_song_2=sp.audio_features(tracks=song_id)

# %%
len(example_song_2)
# Out:
# 30

# %%
example_song_2
# Out:
# [{'danceability': 0.707,
#   'energy': 0.681,
#   'key': 0,
#   'loudness': -4.325,
#   'mode': 1,
#   'speechiness': 0.0668,
#   'acousticness': 0.0632,
#   'instrumentalness': 5.15e-06,
#   'liveness': 0.0322,
#   'valence': 0.646,
#   'tempo': 117.999,
#   'type': 'audio_features',
#   'id': '0yLdNVWF3Srea0uzk55zFn',
#   'uri': 'spotify:track:0yLdNVWF3Srea0uzk55zFn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0yLdNVWF3Srea0uzk55zFn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0yLdNVWF3Srea0uzk55zFn',
#   'duration_ms': 200455,
#   'time_signature': 4},
#  {'danceability': 0.778,
#   'energy': 0.632,
#   'key': 2,
#   'loudness': -5.6,
#   'mode': 0,
#   'speechiness': 0.0493,
#   'acousticness': 0.274,
#   'instrumentalness': 0,
#   'liveness': 0.0915,
#   'valence': 0.498,
#   'tempo': 122.104,
#   'type': 'audio_features',
#   'id': '4nrPB8O7Y7wsOCJdgXkthe',
#   'uri': 'spotify:track:4nrPB8O7Y7wsOCJdgXkthe',
#   'track_href': 'https://api.spotify.com/v1/tracks/4nrPB8O7Y7wsOCJdgXkthe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nrPB8O7Y7wsOCJdgXkthe',
#   'duration_ms': 218289,
#   'time_signature': 4},
#  {'danceability': 0.66,
#   'energy': 0.689,
#   'key': 4,
#   'loudness': -2.671,
#   'mode': 0,
#   'speechiness': 0.0337,
#   'acousticness': 0.0884,
#   'instrumentalness': 0,
#   'liveness': 0.0922,
#   'valence': 0.427,
#   'tempo': 127.98,
#   'type': 'audio_features',
#   'id': '4sOX1nhpKwFWPvoMMExi3q',
#   'uri': 'spotify:track:4sOX1nhpKwFWPvoMMExi3q',
#   'track_href': 'https://api.spotify.com/v1/tracks/4sOX1nhpKwFWPvoMMExi3q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4sOX1nhpKwFWPvoMMExi3q',
#   'duration_ms': 221075,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.704,
#   'key': 9,
#   'loudness': -7.04,
#   'mode': 1,
#   'speechiness': 0.0698,
#   'acousticness': 0.0417,
#   'instrumentalness': 0.00061,
#   'liveness': 0.202,
#   'valence': 0.584,
#   'tempo': 115.123,
#   'type': 'audio_features',
#   'id': '6g4ZPyb7WdvC67X160oKmb',
#   'uri': 'spotify:track:6g4ZPyb7WdvC67X160oKmb',
#   'track_href': 'https://api.spotify.com/v1/tracks/6g4ZPyb7WdvC67X160oKmb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6g4ZPyb7WdvC67X160oKmb',
#   'duration_ms': 217800,
#   'time_signature': 4},
#  {'danceability': 0.647,
#   'energy': 0.728,
#   'key': 2,
#   'loudness': -5.262,
#   'mode': 1,
#   'speechiness': 0.16,
#   'acousticness': 0.0579,
#   'instrumentalness': 0,
#   'liveness': 0.966,
#   'valence': 0.479,
#   'tempo': 100.023,
#   'type': 'audio_features',
#   'id': '61EzFxAX2KM66vmcc2CO1k',
#   'uri': 'spotify:track:61EzFxAX2KM66vmcc2CO1k',
#   'track_href': 'https://api.spotify.com/v1/tracks/61EzFxAX2KM66vmcc2CO1k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61EzFxAX2KM66vmcc2CO1k',
#   'duration_ms': 209573,
#   'time_signature': 4},
#  {'danceability': 0.761,
#   'energy': 0.723,
#   'key': 9,
#   'loudness': -7.386,
#   'mode': 1,
#   'speechiness': 0.0515,
#   'acousticness': 0.097,
#   'instrumentalness': 0.212,
#   'liveness': 0.0997,
#   'valence': 0.462,
#   'tempo': 114.987,
#   'type': 'audio_features',
#   'id': '0xSbYIN12FB1giZI5ymCdz',
#   'uri': 'spotify:track:0xSbYIN12FB1giZI5ymCdz',
#   'track_href': 'https://api.spotify.com/v1/tracks/0xSbYIN12FB1giZI5ymCdz',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xSbYIN12FB1giZI5ymCdz',
#   'duration_ms': 329000,
#   'time_signature': 4},
#  {'danceability': 0.927,
#   'energy': 0.801,
#   'key': 0,
#   'loudness': -4.175,
#   'mode': 1,
#   'speechiness': 0.238,
#   'acousticness': 0.194,
#   'instrumentalness': 0,
#   'liveness': 0.0459,
#   'valence': 0.701,
#   'tempo': 101.986,
#   'type': 'audio_features',
#   'id': '1Qz2w5X6i668NCl1waBzGG',
#   'uri': 'spotify:track:1Qz2w5X6i668NCl1waBzGG',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Qz2w5X6i668NCl1waBzGG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Qz2w5X6i668NCl1waBzGG',
#   'duration_ms': 209107,
#   'time_signature': 4},
#  {'danceability': 0.945,
#   'energy': 0.58,
#   'key': 10,
#   'loudness': -6.33,
#   'mode': 0,
#   'speechiness': 0.0867,
#   'acousticness': 0.509,
#   'instrumentalness': 4.81e-05,
#   'liveness': 0.666,
#   'valence': 0.964,
#   'tempo': 132.991,
#   'type': 'audio_features',
#   'id': '5m4QyDRlKdQmiX1mFnQQij',
#   'uri': 'spotify:track:5m4QyDRlKdQmiX1mFnQQij',
#   'track_href': 'https://api.spotify.com/v1/tracks/5m4QyDRlKdQmiX1mFnQQij',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5m4QyDRlKdQmiX1mFnQQij',
#   'duration_ms': 228085,
#   'time_signature': 4},
#  {'danceability': 0.813,
#   'energy': 0.874,
#   'key': 8,
#   'loudness': -2.73,
#   'mode': 0,
#   'speechiness': 0.277,
#   'acousticness': 0.128,
#   'instrumentalness': 6.84e-06,
#   'liveness': 0.132,
#   'valence': 0.835,
#   'tempo': 129.896,
#   'type': 'audio_features',
#   'id': '0ccNNtxwKNHzzzGI4hIb2z',
#   'uri': 'spotify:track:0ccNNtxwKNHzzzGI4hIb2z',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ccNNtxwKNHzzzGI4hIb2z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ccNNtxwKNHzzzGI4hIb2z',
#   'duration_ms': 211807,
#   'time_signature': 4},
#  {'danceability': 0.822,
#   'energy': 0.864,
#   'key': 9,
#   'loudness': -6.097,
#   'mode': 0,
#   'speechiness': 0.103,
#   'acousticness': 0.386,
#   'instrumentalness': 6.87e-06,
#   'liveness': 0.14,
#   'valence': 0.749,
#   'tempo': 93.999,
#   'type': 'audio_features',
#   'id': '6LsYwZwT0s5w51Z8Y8Fy7T',
#   'uri': 'spotify:track:6LsYwZwT0s5w51Z8Y8Fy7T',
#   'track_href': 'https://api.spotify.com/v1/tracks/6LsYwZwT0s5w51Z8Y8Fy7T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6LsYwZwT0s5w51Z8Y8Fy7T',
#   'duration_ms': 261788,
#   'time_signature': 4},
#  {'danceability': 0.858,
#   'energy': 0.895,
#   'key': 0,
#   'loudness': -2.394,
#   'mode': 1,
#   'speechiness': 0.293,
#   'acousticness': 0.0692,
#   'instrumentalness': 0.000151,
#   'liveness': 0.272,
#   'valence': 0.837,
#   'tempo': 99.794,
#   'type': 'audio_features',
#   'id': '4KcZS9aLgl2AZuRQl5E3c6',
#   'uri': 'spotify:track:4KcZS9aLgl2AZuRQl5E3c6',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KcZS9aLgl2AZuRQl5E3c6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KcZS9aLgl2AZuRQl5E3c6',
#   'duration_ms': 203557,
#   'time_signature': 4},
#  {'danceability': 0.73,
#   'energy': 0.714,
#   'key': 0,
#   'loudness': -2.979,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.0877,
#   'instrumentalness': 0,
#   'liveness': 0.117,
#   'valence': 0.924,
#   'tempo': 94.896,
#   'type': 'audio_features',
#   'id': '2oRtscLLwdLMiDpRoQOSWW',
#   'uri': 'spotify:track:2oRtscLLwdLMiDpRoQOSWW',
#   'track_href': 'https://api.spotify.com/v1/tracks/2oRtscLLwdLMiDpRoQOSWW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2oRtscLLwdLMiDpRoQOSWW',
#   'duration_ms': 202153,
#   'time_signature': 4},
#  {'danceability': 0.555,
#   'energy': 0.634,
#   'key': 6,
#   'loudness': -5.522,
#   'mode': 0,
#   'speechiness': 0.273,
#   'acousticness': 0.129,
#   'instrumentalness': 2.32e-06,
#   'liveness': 0.188,
#   'valence': 0.555,
#   'tempo': 170.228,
#   'type': 'audio_features',
#   'id': '2SiAcexM2p1yX6joESbehd',
#   'uri': 'spotify:track:2SiAcexM2p1yX6joESbehd',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SiAcexM2p1yX6joESbehd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SiAcexM2p1yX6joESbehd',
#   'duration_ms': 174045,
#   'time_signature': 4},
#  {'danceability': 0.6,
#   'energy': 0.691,
#   'key': 5,
#   'loudness': -5.265,
#   'mode': 1,
#   'speechiness': 0.0798,
#   'acousticness': 0.742,
#   'instrumentalness': 0.00021,
#   'liveness': 0.318,
#   'valence': 0.554,
#   'tempo': 116.801,
#   'type': 'audio_features',
#   'id': '0BIotAHhS0t5TUCLfVEZBo',
#   'uri': 'spotify:track:0BIotAHhS0t5TUCLfVEZBo',
#   'track_href': 'https://api.spotify.com/v1/tracks/0BIotAHhS0t5TUCLfVEZBo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BIotAHhS0t5TUCLfVEZBo',
#   'duration_ms': 283500,
#   'time_signature': 3},
#  {'danceability': 0.802,
#   'energy': 0.728,
#   'key': 8,
#   'loudness': -6.456,
#   'mode': 0,
#   'speechiness': 0.0533,
#   'acousticness': 0.0233,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.782,
#   'tempo': 121.92,
#   'type': 'audio_features',
#   'id': '20CozgjF6bshBw8cLhN23B',
#   'uri': 'spotify:track:20CozgjF6bshBw8cLhN23B',
#   'track_href': 'https://api.spotify.com/v1/tracks/20CozgjF6bshBw8cLhN23B',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20CozgjF6bshBw8cLhN23B',
#   'duration_ms': 202185,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.603,
#   'key': 8,
#   'loudness': -5.737,
#   'mode': 1,
#   'speechiness': 0.0325,
#   'acousticness': 0.608,
#   'instrumentalness': 0,
#   'liveness': 0.116,
#   'valence': 0.697,
#   'tempo': 120.048,
#   'type': 'audio_features',
#   'id': '2ERn9fVsix3AyuVv7UN6RC',
#   'uri': 'spotify:track:2ERn9fVsix3AyuVv7UN6RC',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ERn9fVsix3AyuVv7UN6RC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ERn9fVsix3AyuVv7UN6RC',
#   'duration_ms': 197093,
#   'time_signature': 4},
#  {'danceability': 0.83,
#   'energy': 0.615,
#   'key': 9,
#   'loudness': -9.064,
#   'mode': 0,
#   'speechiness': 0.251,
#   'acousticness': 0.119,
#   'instrumentalness': 5.7e-05,
#   'liveness': 0.135,
#   'valence': 0.7,
#   'tempo': 150.117,
#   'type': 'audio_features',
#   'id': '5qDzKUTHCUiKhewBa9STsE',
#   'uri': 'spotify:track:5qDzKUTHCUiKhewBa9STsE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5qDzKUTHCUiKhewBa9STsE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qDzKUTHCUiKhewBa9STsE',
#   'duration_ms': 164200,
#   'time_signature': 4},
#  {'danceability': 0.82,
#   'energy': 0.679,
#   'key': 8,
#   'loudness': -5.333,
#   'mode': 1,
#   'speechiness': 0.0875,
#   'acousticness': 0.482,
#   'instrumentalness': 0,
#   'liveness': 0.105,
#   'valence': 0.516,
#   'tempo': 145.026,
#   'type': 'audio_features',
#   'id': '2toCf2FDbTIdWriPI6kcsY',
#   'uri': 'spotify:track:2toCf2FDbTIdWriPI6kcsY',
#   'track_href': 'https://api.spotify.com/v1/tracks/2toCf2FDbTIdWriPI6kcsY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2toCf2FDbTIdWriPI6kcsY',
#   'duration_ms': 192836,
#   'time_signature': 4},
#  {'danceability': 0.77,
#   'energy': 0.76,
#   'key': 11,
#   'loudness': -6.75,
#   'mode': 0,
#   'speechiness': 0.105,
#   'acousticness': 0.00586,
#   'instrumentalness': 0,
#   'liveness': 0.186,
#   'valence': 0.61,
#   'tempo': 137.943,
#   'type': 'audio_features',
#   'id': '414rOgwyJUcY49sGW5CsZy',
#   'uri': 'spotify:track:414rOgwyJUcY49sGW5CsZy',
#   'track_href': 'https://api.spotify.com/v1/tracks/414rOgwyJUcY49sGW5CsZy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/414rOgwyJUcY49sGW5CsZy',
#   'duration_ms': 231567,
#   'time_signature': 4},
#  {'danceability': 0.874,
#   'energy': 0.869,
#   'key': 1,
#   'loudness': -5.996,
#   'mode': 0,
#   'speechiness': 0.0315,
#   'acousticness': 0.00116,
#   'instrumentalness': 0.00238,
#   'liveness': 0.164,
#   'valence': 0.726,
#   'tempo': 126.027,
#   'type': 'audio_features',
#   'id': '5ZduaRci3iNUiDfJbBfAaf',
#   'uri': 'spotify:track:5ZduaRci3iNUiDfJbBfAaf',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ZduaRci3iNUiDfJbBfAaf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ZduaRci3iNUiDfJbBfAaf',
#   'duration_ms': 102861,
#   'time_signature': 4},
#  {'danceability': 0.804,
#   'energy': 0.645,
#   'key': 6,
#   'loudness': -7.069,
#   'mode': 0,
#   'speechiness': 0.0773,
#   'acousticness': 0.642,
#   'instrumentalness': 0,
#   'liveness': 0.173,
#   'valence': 0.912,
#   'tempo': 142.09,
#   'type': 'audio_features',
#   'id': '7xaqxUl08zOg0YNUHokQpq',
#   'uri': 'spotify:track:7xaqxUl08zOg0YNUHokQpq',
#   'track_href': 'https://api.spotify.com/v1/tracks/7xaqxUl08zOg0YNUHokQpq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xaqxUl08zOg0YNUHokQpq',
#   'duration_ms': 152827,
#   'time_signature': 4},
#  {'danceability': 0.782,
#   'energy': 0.565,
#   'key': 6,
#   'loudness': -7.221,
#   'mode': 0,
#   'speechiness': 0.136,
#   'acousticness': 0.113,
#   'instrumentalness': 0.000634,
#   'liveness': 0.0954,
#   'valence': 0.137,
#   'tempo': 134.962,
#   'type': 'audio_features',
#   'id': '2hP1NjQ0P5B0B5yB2IMf6q',
#   'uri': 'spotify:track:2hP1NjQ0P5B0B5yB2IMf6q',
#   'track_href': 'https://api.spotify.com/v1/tracks/2hP1NjQ0P5B0B5yB2IMf6q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2hP1NjQ0P5B0B5yB2IMf6q',
#   'duration_ms': 202709,
#   'time_signature': 4},
#  {'danceability': 0.602,
#   'energy': 0.91,
#   'key': 7,
#   'loudness': -3.404,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.00126,
#   'instrumentalness': 0.000174,
#   'liveness': 0.12,
#   'valence': 0.228,
#   'tempo': 127.944,
#   'type': 'audio_features',
#   'id': '3BKD1PwArikchz2Zrlp1qi',
#   'uri': 'spotify:track:3BKD1PwArikchz2Zrlp1qi',
#   'track_href': 'https://api.spotify.com/v1/tracks/3BKD1PwArikchz2Zrlp1qi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BKD1PwArikchz2Zrlp1qi',
#   'duration_ms': 140018,
#   'time_signature': 4},
#  {'danceability': 0.777,
#   'energy': 0.73,
#   'key': 6,
#   'loudness': -5.316,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'acousticness': 0.052,
#   'instrumentalness': 0,
#   'liveness': 0.125,
#   'valence': 0.803,
#   'tempo': 129.984,
#   'type': 'audio_features',
#   'id': '5aY2pfyGLxBpuI4TruqmQx',
#   'uri': 'spotify:track:5aY2pfyGLxBpuI4TruqmQx',
#   'track_href': 'https://api.spotify.com/v1/tracks/5aY2pfyGLxBpuI4TruqmQx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5aY2pfyGLxBpuI4TruqmQx',
#   'duration_ms': 165403,
#   'time_signature': 4},
#  {'danceability': 0.592,
#   'energy': 0.96,
#   'key': 1,
#   'loudness': -6.969,
#   'mode': 1,
#   'speechiness': 0.12,
#   'acousticness': 0.0249,
#   'instrumentalness': 0.858,
#   'liveness': 0.445,
#   'valence': 0.0385,
#   'tempo': 135.002,
#   'type': 'audio_features',
#   'id': '1mWbB1bGjvdZR3vFtaT2gL',
#   'uri': 'spotify:track:1mWbB1bGjvdZR3vFtaT2gL',
#   'track_href': 'https://api.spotify.com/v1/tracks/1mWbB1bGjvdZR3vFtaT2gL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mWbB1bGjvdZR3vFtaT2gL',
#   'duration_ms': 248889,
#   'time_signature': 4},
#  {'danceability': 0.678,
#   'energy': 0.538,
#   'key': 6,
#   'loudness': -16.121,
#   'mode': 1,
#   'speechiness': 0.158,
#   'acousticness': 0.632,
#   'instrumentalness': 0.935,
#   'liveness': 0.112,
#   'valence': 0.291,
#   'tempo': 136.986,
#   'type': 'audio_features',
#   'id': '0UYjebmO93HnkBaac49FMu',
#   'uri': 'spotify:track:0UYjebmO93HnkBaac49FMu',
#   'track_href': 'https://api.spotify.com/v1/tracks/0UYjebmO93HnkBaac49FMu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0UYjebmO93HnkBaac49FMu',
#   'duration_ms': 485255,
#   'time_signature': 4},
#  {'danceability': 0.703,
#   'energy': 0.594,
#   'key': 1,
#   'loudness': -15.863,
#   'mode': 1,
#   'speechiness': 0.0668,
#   'acousticness': 0.199,
#   'instrumentalness': 0.951,
#   'liveness': 0.08,
#   'valence': 0.406,
#   'tempo': 127.002,
#   'type': 'audio_features',
#   'id': '3UCY8UXQRBgbNlbT4cW2Cq',
#   'uri': 'spotify:track:3UCY8UXQRBgbNlbT4cW2Cq',
#   'track_href': 'https://api.spotify.com/v1/tracks/3UCY8UXQRBgbNlbT4cW2Cq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UCY8UXQRBgbNlbT4cW2Cq',
#   'duration_ms': 364000,
#   'time_signature': 4},
#  {'danceability': 0.783,
#   'energy': 0.716,
#   'key': 8,
#   'loudness': -7.445,
#   'mode': 1,
#   'speechiness': 0.0528,
#   'acousticness': 0.0014,
#   'instrumentalness': 0.751,
#   'liveness': 0.119,
#   'valence': 0.297,
#   'tempo': 133.997,
#   'type': 'audio_features',
#   'id': '21WIoAisDlLyEsRAZX35CT',
#   'uri': 'spotify:track:21WIoAisDlLyEsRAZX35CT',
#   'track_href': 'https://api.spotify.com/v1/tracks/21WIoAisDlLyEsRAZX35CT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21WIoAisDlLyEsRAZX35CT',
#   'duration_ms': 406585,
#   'time_signature': 4},
#  {'danceability': 0.843,
#   'energy': 0.628,
#   'key': 7,
#   'loudness': -10.034,
#   'mode': 1,
#   'speechiness': 0.132,
#   'acousticness': 0.233,
#   'instrumentalness': 0.835,
#   'liveness': 0.0923,
#   'valence': 0.0364,
#   'tempo': 133.006,
#   'type': 'audio_features',
#   'id': '3gaIIBUh8npzwh1ObuEVdM',
#   'uri': 'spotify:track:3gaIIBUh8npzwh1ObuEVdM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3gaIIBUh8npzwh1ObuEVdM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gaIIBUh8npzwh1ObuEVdM',
#   'duration_ms': 350075,
#   'time_signature': 4},
#  {'danceability': 0.767,
#   'energy': 0.888,
#   'key': 2,
#   'loudness': -5.262,
#   'mode': 1,
#   'speechiness': 0.0597,
#   'acousticness': 0.000494,
#   'instrumentalness': 0.894,
#   'liveness': 0.0599,
#   'valence': 0.388,
#   'tempo': 132.998,
#   'type': 'audio_features',
#   'id': '2Vn9JwANzvfh4g3yLVCbqL',
#   'uri': 'spotify:track:2Vn9JwANzvfh4g3yLVCbqL',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Vn9JwANzvfh4g3yLVCbqL',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Vn9JwANzvfh4g3yLVCbqL',
#   'duration_ms': 416000,
#   'time_signature': 4}]
